# %% [markdown]
# # Import libraries

# %%
# data manipulation
import pandas as pd

# visualization
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# galeritas imports
import sys
sys.path.append('../../')
from galeritas.plot_calibration_and_distribution import plot_calibration_and_distribution
from galeritas import get_palette

# %%
# global configurations for visualizations
sns.set(rc={'figure.figsize':(12,8)})
sns.set_style('white')
sns.set_palette(get_palette())

# %% [markdown]
# # Open datasets

# %%
titanic = pd.read_csv('../../tests/data/titanic.csv')

# %% [markdown]
# # Basic plot

# %% [markdown]
# Plot Calibration curve and Distribution of predicted values
#
# Basic parameters are:
#
# `data`: dataframe contaning target and predicted value columns
#
# `target`: name of target column (0's and 1's)
#
# `predictions`: name of predicted values column (array in [0, 1] range)
#
# for other parameters refer to plot documentation:
#
# https://github.com/Creditas/galeritas/blob/main/galeritas/plot_calibration_and_distribution.py

# %%
plot_calibration_and_distribution(data=titanic, target='survived', predictions='predict_proba')
