# %% [markdown]
# # Import libraries

# %%
# data manipulation
import pandas as pd

# visualization
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# galeritas imports
import sys
sys.path.append('../../')
from galeritas.plot_ks_classification import plot_ks_classification
from galeritas import get_palette

# %%
# global configurations for visualizations
sns.set(rc={'figure.figsize':(12,8)})
sns.set_style('white')
sns.set_palette(get_palette())

# %% [markdown]
# # Open datasets

# %%
titanic = pd.read_csv('../../tests/data/titanic.csv')

# %% [markdown]
# # Basic plot

# %% [markdown]
# Plot KS curve for predicted value and true value.
#
# `y_pred` should be an array [0, 1] (if is in and different range, then pass min_max_scale as a tuple (min, max) for scaling to [0, 1]
#
# `y_true` should be an array of 0's and 1's
#
# for other parameters refer to plot documentation:
#
# https://github.com/Creditas/galeritas/blob/main/galeritas/plot_ks_classification.py

# %%
plot_ks_classification(titanic['predict_proba'], titanic['survived'])
